# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from importlib import reload
import scripts.data_load_clean_transform, scripts.insurance_analysis, scripts.hypothesis_test
reload(scripts.data_load_clean_transform)
reload(scripts.insurance_analysis)
reload(scripts.hypothesis_test)
# Out:
# <module 'scripts.hypothesis_test' from 'c:\\ML and DS Files\\Kifiya AI\\Kaim-week-3\\scripts\\hypothesis_test.py'>

# %%
from scripts.data_load_clean_transform import DataLoader, DataCleaner
from scripts.insurance_analysis import DataAnalyzer
from scripts.hypothesis_test import ABHypothesisTesting

# %%
file_path = '../week 3 data/Data/MachineLearningRating_v3/preprocessed/preprocessed_insurance.csv'
loader = DataLoader(file_path)
data = loader.load_data()
# Out:
# Data successfully loaded from ../week 3 data/Data/MachineLearningRating_v3/preprocessed/preprocessed_insurance.csv

# %%
data.head(2)
# Out:
#    UnderwrittenCoverID  PolicyID           TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00+00:00             True
# 1               145249     12827  2015-05-01 00:00:00+00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...         ExcessSelected CoverCategory   CoverType  \
# 0  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
# 1  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
#
#              CoverGroup              Section                          Product  \
# 0  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium TotalClaims
# ...

# %%
data_check = DataCleaner(data)
data_check.check_missing_values()
# Out:
#                       Column  Missing Values  Missing Percentage Data Type
# 0        UnderwrittenCoverID               0            0.000000     int64
# 1                   PolicyID               0            0.000000     int64
# 2           TransactionMonth               0            0.000000    object
# 3            IsVATRegistered               0            0.000000      bool
# 4                Citizenship               0            0.000000    object
# 5                  LegalType               0            0.000000    object
# 6                      Title               0            0.000000    object
# 7                   Language               0            0.000000    object
# 8                       Bank           32857           19.966820    object
# 9                AccountType           29882           18.158947    object
# 10             MaritalStatus               0            0.000000    object
# ...

# %% [markdown]
# # Hypothesis testing

# %%
# Initialize the tester
tester = ABHypothesisTesting(data)

# %%
# select kpi
tester.select_kpi("TotalClaims")
# Out:
# Selected KPI: TotalClaims

# %%
# Segment data
tester.segment_data("Province", "Gauteng", "Kwazulu-Natal")
# Out:
# Successfully segmented data. Group A size: 87390, Group B size: 27704

# %%
# Perform statistical test
p_value = tester.perform_statistical_test("t-test")
# Out:
# Performed t-test. p-value: 0.5147235113606493

# %%
# Evaluate hypothesis
tester.evaluate_hypothesis(p_value)
# Out:
# Fail to reject the null hypothesis: No significant differences detected.
# 'Fail to reject the null hypothesis: No significant differences detected.'

# %%
# Generate a report
analysis = {
    "Selected KPI": tester.kpi,
    "Group A Size": len(tester.group_a),
    "Group B Size": len(tester.group_b),
    "Statistical Test": "t-test",
    "P-Value": p_value,
    "Result": tester.evaluate_hypothesis(p_value),
}

# Print the report
print("\n--- A/B Hypothesis Test Report ---")
for key, value in analysis.items():
    print(f"{key}: {value}")
# Out:
# Fail to reject the null hypothesis: No significant differences detected.
#
# --- A/B Hypothesis Test Report ---
# Selected KPI: TotalClaims
# Group A Size: 87390
# Group B Size: 27704
# Statistical Test: t-test
# P-Value: 0.5147235113606493
# Result: Fail to reject the null hypothesis: No significant differences detected.
